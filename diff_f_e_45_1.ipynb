# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
stop_45 = pd.read_csv('data/stop_45_quat.csv', sep=",")
stop_45_without_speed = stop_45
euler=stop_45[['e_r_x','e_r_y','e_r_z','e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
stop_45_diff = stop_45_without_speed.diff()
stop_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler
stop_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.127  0.587  0.770  0.215    NaN    NaN    NaN
# 1    -0.001  0.000 -0.001 -0.127  0.588  0.770  0.215  0.000  0.000    0.0
# 2     0.001  0.000  0.000 -0.126  0.588  0.769  0.215  0.000  0.000    0.0
# 3     0.000  0.001  0.000 -0.126  0.590  0.768  0.215  0.000  0.001    0.0
# 4    -0.001  0.000  0.000 -0.127  0.591  0.768  0.213 -0.001  0.000    0.0
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.000  0.000  0.000 -0.687  0.171  0.422  0.566  0.000  0.000    0.0
# 1196  0.000  0.000  0.000 -0.687  0.170  0.422  0.566  0.000 -0.001    0.0
# 1197  0.000  0.000  0.000 -0.688  0.169  0.422  0.566  0.000  0.000    0.0
# 1198  0.000 -0.001 -0.001 -0.688  0.166  0.423  0.566  0.000  0.000    0.0
# 1199  0.000 -0.001  0.000 -0.690  0.159  0.421  0.567 -0.001  0.000    0.0
#
# ...

# %%
forward_45 = pd.read_csv('data/0_45_quat.csv', sep=",")
forward_45_without_speed = forward_45[forward_45.columns[:-1]]
euler_forward_45=forward_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
forward_45_diff = forward_45_without_speed.diff()
forward_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_forward_45
forward_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.726  0.099  0.334  0.592    NaN    NaN    NaN
# 1     0.012  0.003 -0.009 -0.768  0.005  0.178  0.615  0.001 -0.001  0.000
# 2     0.003  0.001  0.001 -0.766  0.020  0.173  0.619  0.000  0.001  0.000
# 3     0.000  0.001  0.000 -0.765  0.015  0.173  0.620  0.000  0.001 -0.001
# 4     0.001 -0.001  0.000 -0.762  0.014  0.174  0.623 -0.002  0.001 -0.001
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.000  0.000  0.000  0.008  0.584  0.803  0.121 -0.036 -0.013  0.022
# 1196  0.001  0.000  0.000  0.008  0.580  0.806  0.122 -0.050 -0.044 -0.100
# 1197 -0.001  0.000  0.001  0.008  0.576  0.809  0.120 -0.062 -0.029 -0.132
# 1198  0.000  0.000  0.000  0.008  0.574  0.810  0.120 -0.032 -0.012 -0.092
# 1199  0.001 -0.001  0.002  0.010  0.562  0.817  0.127  0.002  0.002 -0.007
#
# ...

# %%
d_f_e_45 = pd.read_csv('data/45_45_quat.csv', sep=",")
d_f_e_45_without_speed = d_f_e_45[d_f_e_45.columns[:-1]]
euler_d_f_e_45=d_f_e_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
d_f_e_45_diff = d_f_e_45_without_speed.diff()
d_f_e_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_d_f_e_45
d_f_e_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN  0.009  0.521  0.845  0.121    NaN    NaN    NaN
# 1     0.006  0.024  0.077 -0.016  0.407  0.900  0.157  0.002 -0.001  0.000
# 2    -0.004  0.015  0.134 -0.034  0.575  0.802  0.157  0.002  0.002  0.000
# 3    -0.037  0.026  0.121 -0.071  0.669  0.713  0.198  0.000  0.000  0.000
# 4     0.005 -0.007  0.005 -0.040  0.655  0.743  0.131  0.000 -0.001  0.001
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195 -0.009  0.002  0.012 -0.270  0.550  0.716  0.336  0.000  0.000  0.000
# 1196  0.054 -0.021 -0.072 -0.291  0.529  0.716  0.350 -0.001  0.000  0.001
# 1197  0.086 -0.017 -0.092 -0.289  0.523  0.733  0.326 -0.001 -0.001  0.000
# 1198  0.068 -0.009 -0.067 -0.285  0.508  0.746  0.322  0.001 -0.001  0.000
# 1199  0.009 -0.001 -0.009 -0.294  0.497  0.755  0.310  0.000  0.001  0.005
#
# ...

# %%
left_45 = pd.read_csv('data/90_45_quat.csv', sep=",")
left_45_without_speed =left_45
euler_left_45=left_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
left_45_diff =left_45_without_speed.diff()
left_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_left_45
left_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.290  0.504  0.748  0.320    NaN    NaN    NaN
# 1     0.000  0.000  0.001 -0.293  0.502  0.749  0.318 -0.056  0.025  0.097
# 2     0.000  0.000  0.000 -0.292  0.502  0.749  0.318 -0.066  0.020  0.121
# 3     0.000  0.000 -0.001 -0.291  0.502  0.750  0.319 -0.039  0.023  0.079
# 4     0.000  0.000  0.001 -0.290  0.498  0.751  0.321 -0.020 -0.009 -0.010
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.100 -0.007  0.005 -0.577  0.314  0.557  0.507  0.000 -0.001  0.000
# 1196  0.033  0.000 -0.002 -0.581  0.312  0.547  0.516 -0.003  0.000  0.001
# 1197 -0.002 -0.002  0.000 -0.587  0.309  0.555  0.503 -0.015  0.002  0.005
# 1198 -0.002  0.001  0.000 -0.585  0.306  0.555  0.506 -0.071  0.017  0.002
# 1199  0.000  0.000  0.000 -0.586  0.307  0.555  0.504 -0.155  0.011  0.005
#
# ...

# %%
d_t_e_45 = pd.read_csv('data/135_45_quat.csv', sep=",")
d_t_e_45_without_speed = d_t_e_45[d_t_e_45.columns[:-1]]
euler_d_t_e_45=d_t_e_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
d_t_e_45_diff = d_t_e_45_without_speed.diff()
d_t_e_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_d_t_e_45
d_t_e_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.585  0.306  0.555  0.505    NaN    NaN    NaN
# 1    -0.001  0.001  0.000 -0.585  0.304  0.556  0.505 -0.003  0.004 -0.001
# 2     0.000  0.000  0.000 -0.585  0.303  0.557  0.506  0.074 -0.027  0.006
# 3     0.000  0.000  0.000 -0.585  0.301  0.559  0.505  0.157 -0.026 -0.019
# 4     0.000  0.000  0.000 -0.585  0.300  0.559  0.505  0.094 -0.009 -0.020
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.000  0.000  0.000 -0.749  0.098  0.315  0.575  0.053 -0.026  0.043
# 1196 -0.001  0.000  0.000 -0.749  0.097  0.316  0.573  0.126 -0.025  0.067
# 1197  0.000  0.000  0.000 -0.749  0.097  0.317  0.574  0.109 -0.008  0.061
# 1198  0.001  0.001  0.000 -0.752  0.094  0.318  0.570  0.053 -0.002  0.038
# 1199 -0.004  0.002 -0.005 -0.788  0.070  0.312  0.526 -0.009  0.001 -0.001
#
# ...

# %%
backward_45 = pd.read_csv('data/180_45_quat.csv', sep=",")
backward_45_without_speed = backward_45
euler_backward_45=backward_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
backward_45_diff = backward_45_without_speed.diff()
backward_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_backward_45
backward_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.817 -0.049  0.355  0.452    NaN    NaN    NaN
# 1    -0.100  0.012 -0.086 -0.758  0.078  0.300  0.574  0.001 -0.001  0.000
# 2    -0.044  0.024 -0.101 -0.700  0.065  0.245  0.668  0.002 -0.002  0.000
# 3    -0.006 -0.006 -0.013 -0.712  0.094  0.269  0.642  0.001 -0.002  0.000
# 4     0.053 -0.014  0.051 -0.729  0.072  0.251  0.633  0.002 -0.001  0.000
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.001  0.001 -0.001 -0.812 -0.169 -0.033  0.557  0.037 -0.030  0.124
# 1196 -0.001  0.001  0.001 -0.813 -0.167 -0.032  0.557  0.028 -0.017  0.137
# 1197  0.000  0.000  0.000 -0.815 -0.169 -0.034  0.554  0.003 -0.001  0.072
# 1198  0.003  0.000 -0.002 -0.835 -0.177 -0.049  0.519 -0.002 -0.002 -0.009
# 1199 -0.007  0.010 -0.041 -0.919 -0.243 -0.030  0.308  0.001 -0.001 -0.003
#
# ...

# %%
d_t_d_45 = pd.read_csv('data/225_45_quat.csv', sep=",")
d_t_d_45_without_speed = d_t_d_45[d_t_d_45.columns[:-1]]
euler_d_t_d_45=d_t_d_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
d_t_d_45_diff = d_t_d_45_without_speed.diff()
d_t_d_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_d_t_d_45
d_t_d_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.862 -0.133  0.000  0.489    NaN    NaN    NaN
# 1     0.019  0.024 -0.156 -0.758 -0.138 -0.027  0.637 -0.001  0.000  0.000
# 2     0.016  0.011 -0.061 -0.729 -0.151  0.010  0.668  0.001 -0.001  0.000
# 3     0.008 -0.019  0.057 -0.776 -0.127  0.004  0.618  0.000  0.001 -0.001
# 4    -0.007 -0.023  0.109 -0.794 -0.126  0.014  0.594  0.000 -0.001 -0.001
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.079  0.024 -0.029 -0.673 -0.454 -0.227  0.538  0.000  0.000  0.000
# 1196 -0.018 -0.021  0.006 -0.708 -0.397 -0.254  0.526  0.000  0.000  0.000
# 1197 -0.070 -0.024  0.055 -0.708 -0.395 -0.306  0.499  0.001  0.000  0.000
# 1198 -0.115 -0.023  0.053 -0.722 -0.372 -0.322  0.486  0.000  0.000 -0.001
# 1199 -0.108 -0.013  0.041 -0.738 -0.348 -0.303  0.492 -0.001  0.000  0.001
#
# ...

# %%
right_45 = pd.read_csv('data/270_45_quat.csv', sep=",")
right_45_without_speed = right_45
euler_right_45=right_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
right_45_diff = right_45_without_speed.diff()
right_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_right_45
right_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.730 -0.358 -0.333  0.479    NaN    NaN    NaN
# 1     0.006 -0.003 -0.004 -0.731 -0.360 -0.324  0.481  0.003  0.002 -0.005
# 2     0.001 -0.001 -0.002 -0.739 -0.353 -0.330  0.470  0.016  0.012 -0.049
# 3     0.000  0.000  0.000 -0.739 -0.353 -0.330  0.470  0.014  0.020 -0.136
# 4     0.000 -0.001  0.000 -0.739 -0.357 -0.327  0.469 -0.016  0.035 -0.140
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195  0.000  0.001  0.000 -0.549 -0.516 -0.588  0.296  0.032  0.010  0.007
# 1196  0.001  0.000 -0.001 -0.550 -0.517 -0.587  0.293 -0.065 -0.019  0.016
# 1197  0.001  0.000  0.000 -0.552 -0.516 -0.587  0.291 -0.107 -0.025  0.035
# 1198 -0.001  0.000  0.000 -0.551 -0.517 -0.587  0.290 -0.114 -0.014  0.020
# 1199  0.000  0.001  0.000 -0.551 -0.516 -0.588  0.289 -0.058 -0.001  0.006
#
# ...

# %%
d_f_d_45 = pd.read_csv('data/315_45_quat.csv', sep=",")
d_f_d_45_without_speed = d_f_d_45[d_f_d_45.columns[:-1]]
euler_d_f_d_45=d_f_d_45[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
d_f_d_45_diff = d_f_d_45_without_speed.diff()
d_f_d_45_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_d_f_d_45
d_f_d_45_diff
# Out:
#       e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0       NaN    NaN    NaN -0.558 -0.501 -0.606  0.267    NaN    NaN    NaN
# 1     0.015  0.003  0.005 -0.549 -0.455 -0.678  0.180  0.001  0.000  0.001
# 2     0.097  0.012 -0.014 -0.541 -0.501 -0.639  0.218  0.001  0.000  0.000
# 3     0.139  0.018  0.001 -0.515 -0.544 -0.570  0.338  0.000  0.000  0.000
# 4     0.091  0.022  0.022 -0.508 -0.581 -0.534  0.344  0.001 -0.001  0.001
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1195 -0.013 -0.002 -0.020 -0.261 -0.604 -0.749  0.075  0.000  0.000  0.000
# 1196  0.001 -0.001  0.003 -0.266 -0.592 -0.757  0.078  0.004  0.001  0.003
# 1197  0.001 -0.001  0.001 -0.267 -0.592 -0.757  0.076  0.011  0.001  0.005
# 1198  0.001 -0.001  0.000 -0.268 -0.593 -0.756  0.073  0.080  0.024  0.026
# 1199  0.000  0.000  0.000 -0.269 -0.593 -0.755  0.071  0.137  0.022  0.014
#
# ...

# %%
# stop = stop_passado.append(stop_90_diff, ignore_index=True)
# forward = frente_passado.append(forward_90_diff, ignore_index=True)
# left = esquerda_passado.append(left_90_diff, ignore_index=True)
# backward = tras_passado.append(backward_90_diff, ignore_index=True)
# right = direita_passado.append(right_90_diff, ignore_index=True)

# %%
# stop_passado = pd.read_csv('data/stop_90_diff_quat.csv', sep=",")
# frente_passado = pd.read_csv('data/0_90_diff_quat.csv', sep=",")
# esquerda_passado = pd.read_csv('data/90_90_diff_quat.csv', sep=",")
# tras_passado = pd.read_csv('data/180_90_diff_quat.csv', sep=",")
# direita_passado = pd.read_csv('data/270_90_diff_quat.csv', sep=",")

# %%
# stop = stop_passado.append(stop_90_diff, ignore_index=True)
# forward = frente_passado.append(forward_90_diff, ignore_index=True)
# left = esquerda_passado.append(left_90_diff, ignore_index=True)
# backward = tras_passado.append(backward_90_diff, ignore_index=True)
# right = direita_passado.append(right_90_diff, ignore_index=True)

# %%
# stop.to_csv('stop_90_diff_quat.csv', index=False, header=True)
# forward.to_csv('0_90_diff_quat.csv', index=False, header=True)
# left.to_csv('90_90_diff_quat.csv', index=False, header=True)
# backward.to_csv('180_90_diff_quat.csv', index=False, header=True)
# right.to_csv('270_90_diff_quat.csv', index=False, header=True)

# %%
stop_45_diff.to_csv('data/stop_45_diff_quat.csv', index=False, header=True)
forward_45_diff.to_csv('data/0_45_diff_quat.csv', index=False, header=True)
d_f_e_45_diff.to_csv('data/45_45_diff_quat.csv', index=False, header=True)
left_45_diff.to_csv('data/90_45_diff_quat.csv', index=False, header=True)
d_t_e_45_diff.to_csv('data/135_45_diff_quat.csv', index=False, header=True)
backward_45_diff.to_csv('data/180_45_diff_quat.csv', index=False, header=True)
d_t_d_45_diff.to_csv('data/225_45_diff_quat.csv', index=False, header=True)
right_45_diff.to_csv('data/270_45_diff_quat.csv', index=False, header=True)
d_f_d_45_diff.to_csv('data/315_45_diff_quat.csv', index=False, header=True)
