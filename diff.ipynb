# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
stop_90 = pd.read_csv('data/stop_90_quat.csv', sep=",")
stop_90_without_speed = stop_90[stop_90.columns[:-1]]
stop_90_without_speed
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0     -0.331  0.652  0.209  0.004000  0.677000  0.736000  0.010000  0.313
# 1     -0.331  0.652  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 2     -0.331  0.651  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 3     -0.331  0.652  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 4     -0.331  0.652  0.209  0.004000  0.678000  0.735000  0.010000  0.313
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 71991  0.176  0.614  0.125  0.404585 -0.912552  0.009292 -0.058940  0.174
# 71992  0.176  0.613  0.125  0.404578 -0.912570  0.010219 -0.058557  0.174
# 71993  0.176  0.613  0.125  0.404578 -0.912570  0.010219 -0.058557  0.174
# 71994  0.176  0.613  0.125  0.404578 -0.912570  0.010219 -0.058557  0.175
# 71995  0.176  0.613  0.125  0.404578 -0.912570  0.010219 -0.058557  0.175
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0      0.643  0.216  ...  0.616000  0.752000  0.071000 -0.028  2.288  0.179
# 1      0.643  0.216  ...  0.616000  0.753000  0.071000 -0.021  2.288  0.180
# 2      0.643  0.217  ...  0.616000  0.752000  0.071000 -0.013  2.288  0.181
# 3      0.643  0.216  ...  0.616000  0.752000  0.071000 -0.004  2.287  0.181
# 4      0.643  0.216  ...  0.616000  0.752000  0.071000  0.002  2.287  0.180
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.610 -0.133  ...  0.903371  0.094861  0.060991 -0.002  2.290  0.188
# 71992  0.610 -0.133  ...  0.903984  0.095296  0.060016 -0.009  2.289  0.189
# 71993  0.609 -0.133  ...  0.903984  0.095296  0.060016 -0.014  2.289  0.185
# 71994  0.610 -0.132  ...  0.903397  0.095244  0.060066 -0.022  2.293  0.180
# 71995  0.610 -0.133  ...  0.903984  0.095296  0.060016 -0.031  2.292  0.172
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0     -0.100 -0.025 -0.045  0.994
# 1     -0.106 -0.014 -0.054  0.993
# 2     -0.104 -0.001 -0.062  0.993
# 3     -0.106  0.014 -0.069  0.992
# 4     -0.105  0.023 -0.073  0.992
# ...      ...    ...    ...    ...
# 71991  0.016 -0.045 -0.003  0.999
# 71992  0.018 -0.071  0.004  0.997
# 71993  0.024 -0.083  0.010  0.996
# 71994  0.010 -0.094  0.026  0.995
# 71995  0.005 -0.117  0.057  0.991
#
# [71996 rows x 21 columns]

# %%
euler=stop_90[['e_r_x','e_r_y','e_r_z','e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
euler
# Out:
#           e_r_x     e_r_y     e_r_z     e_r_w     d_r_x     d_r_y     d_r_z  \
# 0      0.004000  0.677000  0.736000  0.010000  0.221000  0.616000  0.752000
# 1      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.753000
# 2      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.752000
# 3      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.752000
# 4      0.004000  0.678000  0.735000  0.010000  0.221000  0.616000  0.752000
# ...         ...       ...       ...       ...       ...       ...       ...
# 71991  0.404585 -0.912552  0.009292 -0.058940 -0.413766  0.903371  0.094861
# 71992  0.404578 -0.912570  0.010219 -0.058557 -0.412468  0.903984  0.095296
# 71993  0.404578 -0.912570  0.010219 -0.058557 -0.412468  0.903984  0.095296
# 71994  0.404578 -0.912570  0.010219 -0.058557 -0.413756  0.903397  0.095244
# 71995  0.404578 -0.912570  0.010219 -0.058557 -0.412468  0.903984  0.095296
#
#           d_r_w
# 0      0.071000
# 1      0.071000
# 2      0.071000
# 3      0.071000
# 4      0.071000
# ...         ...
# 71991  0.060991
# 71992  0.060016
# 71993  0.060016
# 71994  0.060066
# 71995  0.060016
#
# [71996 rows x 8 columns]

# %%
stop_90_diff = stop_90_without_speed.diff()
stop_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN       NaN       NaN       NaN       NaN    NaN
# 1        0.0  0.000    0.0  0.000000  0.000000 -0.001000  0.000000  0.000
# 2        0.0 -0.001    0.0  0.000000  0.000000  0.000000  0.000000  0.000
# 3        0.0  0.001    0.0  0.000000  0.000000  0.000000  0.000000  0.000
# 4        0.0  0.000    0.0  0.000000  0.001000  0.000000  0.000000  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 71991    0.0  0.001    0.0  0.000029  0.000076  0.000374 -0.000925 -0.002
# 71992    0.0 -0.001    0.0 -0.000007 -0.000018  0.000926  0.000383  0.000
# 71993    0.0  0.000    0.0  0.000000  0.000000  0.000000  0.000000  0.000
# 71994    0.0  0.000    0.0  0.000000  0.000000  0.000000  0.000000  0.001
# 71995    0.0  0.000    0.0  0.000000  0.000000  0.000000  0.000000  0.000
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...       NaN       NaN       NaN    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.000000  0.001000  0.000000  0.007  0.000  0.001
# 2      0.000  0.001  ...  0.000000 -0.001000  0.000000  0.008  0.000  0.001
# 3      0.000 -0.001  ...  0.000000  0.000000  0.000000  0.009 -0.001  0.000
# 4      0.000  0.000  ...  0.000000  0.000000  0.000000  0.006  0.000 -0.001
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.000  0.000  ... -0.000147  0.000916  0.000391 -0.024  0.002  0.005
# 71992  0.000  0.000  ...  0.000613  0.000435 -0.000975 -0.007 -0.001  0.001
# 71993 -0.001  0.000  ...  0.000000  0.000000  0.000000 -0.005  0.000 -0.004
# 71994  0.001  0.001  ... -0.000587 -0.000053  0.000050 -0.008  0.004 -0.005
# 71995  0.000 -0.001  ...  0.000587  0.000053 -0.000050 -0.009 -0.001 -0.008
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1     -0.006  0.011 -0.009 -0.001
# 2      0.002  0.013 -0.008  0.000
# 3     -0.002  0.015 -0.007 -0.001
# 4      0.001  0.009 -0.004  0.000
# ...      ...    ...    ...    ...
# 71991 -0.002 -0.098  0.008  0.001
# 71992  0.002 -0.026  0.007 -0.002
# 71993  0.006 -0.012  0.006 -0.001
# 71994 -0.014 -0.011  0.016 -0.001
# 71995 -0.005 -0.023  0.031 -0.004
#
# [71996 rows x 21 columns]

# %%
stop_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler
stop_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.004000  0.677000  0.736000  0.010000    NaN
# 1        0.0  0.000    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 2        0.0 -0.001    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 3        0.0  0.001    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 4        0.0  0.000    0.0  0.004000  0.678000  0.735000  0.010000  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 71991    0.0  0.001    0.0  0.404585 -0.912552  0.009292 -0.058940 -0.002
# 71992    0.0 -0.001    0.0  0.404578 -0.912570  0.010219 -0.058557  0.000
# 71993    0.0  0.000    0.0  0.404578 -0.912570  0.010219 -0.058557  0.000
# 71994    0.0  0.000    0.0  0.404578 -0.912570  0.010219 -0.058557  0.001
# 71995    0.0  0.000    0.0  0.404578 -0.912570  0.010219 -0.058557  0.000
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.616000  0.752000  0.071000    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.616000  0.753000  0.071000  0.007  0.000  0.001
# 2      0.000  0.001  ...  0.616000  0.752000  0.071000  0.008  0.000  0.001
# 3      0.000 -0.001  ...  0.616000  0.752000  0.071000  0.009 -0.001  0.000
# 4      0.000  0.000  ...  0.616000  0.752000  0.071000  0.006  0.000 -0.001
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.000  0.000  ...  0.903371  0.094861  0.060991 -0.024  0.002  0.005
# 71992  0.000  0.000  ...  0.903984  0.095296  0.060016 -0.007 -0.001  0.001
# 71993 -0.001  0.000  ...  0.903984  0.095296  0.060016 -0.005  0.000 -0.004
# 71994  0.001  0.001  ...  0.903397  0.095244  0.060066 -0.008  0.004 -0.005
# 71995  0.000 -0.001  ...  0.903984  0.095296  0.060016 -0.009 -0.001 -0.008
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1     -0.006  0.011 -0.009 -0.001
# 2      0.002  0.013 -0.008  0.000
# 3     -0.002  0.015 -0.007 -0.001
# 4      0.001  0.009 -0.004  0.000
# ...      ...    ...    ...    ...
# 71991 -0.002 -0.098  0.008  0.001
# 71992  0.002 -0.026  0.007 -0.002
# 71993  0.006 -0.012  0.006 -0.001
# 71994 -0.014 -0.011  0.016 -0.001
# 71995 -0.005 -0.023  0.031 -0.004
#
# [71996 rows x 21 columns]

# %%
forward_90 = pd.read_csv('data/0_90_quat.csv', sep=",")
forward_90_without_speed = forward_90[forward_90.columns[:-1]]
euler_forward_90=forward_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
forward_90_diff = forward_90_without_speed.diff()
forward_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_forward_90
forward_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0        NaN    NaN    NaN  0.006 -0.654 -0.756  0.015    NaN    NaN    NaN
# 1      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 2      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 3      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 4      0.000  0.000  0.000  0.006 -0.655 -0.756  0.014  0.000  0.000  0.000
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 23993 -0.030  0.031  0.113 -0.035  0.666  0.745  0.019 -0.001 -0.002  0.000
# 23994 -0.005  0.024  0.133  0.067 -0.750 -0.658  0.010  0.000 -0.002 -0.002
# 23995 -0.005  0.006  0.061 -0.085  0.753  0.652  0.006 -0.001 -0.002 -0.002
# 23996  0.010 -0.014 -0.056  0.032 -0.745 -0.666  0.031 -0.001 -0.001 -0.002
# 23997  0.007 -0.023 -0.086 -0.002 -0.726 -0.685  0.062  0.001  0.001 -0.001
#
#        ...  d_r_y  d_r_z  d_r_w  c_t_x  c_t_y  c_t_z  c_r_x  c_r_y  c_r_z  \
# 0      ...  0.587  0.769  0.121    NaN    NaN    NaN    NaN    NaN    NaN
# 1      ...  0.587  0.769  0.121  0.000 -0.001  0.004  0.002  0.005  0.001
# 2      ...  0.587  0.769  0.121 -0.002 -0.001  0.004  0.003 -0.002 -0.001
# 3      ...  0.587  0.769  0.121  0.000 -0.001  0.003  0.004 -0.001  0.000
# 4      ...  0.587  0.769  0.123 -0.002 -0.001  0.004  0.002 -0.001  0.000
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 23993  ...  0.671  0.737  0.009  0.011  0.003 -0.006  0.003 -0.001 -0.006
# 23994  ...  0.670  0.738  0.007 -0.001 -0.001  0.001 -0.005  0.004  0.000
# 23995  ...  0.671  0.737  0.011 -0.012 -0.003  0.006  0.005  0.006  0.006
# 23996  ...  0.669  0.739  0.007 -0.023  0.001  0.010  0.001 -0.001  0.011
# 23997  ...  0.671  0.737  0.010 -0.030  0.001  0.004  0.005 -0.011  0.016
#
#        c_r_w
# 0        NaN
# 1      0.000
# 2      0.000
# 3      0.000
# 4      0.000
# ...      ...
# 23993  0.000
# 23994  0.000
# 23995  0.000
# 23996  0.001
# 23997  0.000
#
# [23998 rows x 21 columns]

# %%
left_90 = pd.read_csv('data/90_90_quat.csv', sep=",")
left_90_without_speed =left_90[left_90.columns[:-1]]
euler_left_90=left_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
left_90_diff =left_90_without_speed.diff()
left_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_left_90
left_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.071902 -0.997281  0.014862 -0.006360    NaN
# 1      0.000  0.000  0.000  0.071794 -0.997289  0.014828 -0.006371  0.000
# 2      0.000  0.000  0.000  0.071794 -0.997289  0.014828 -0.006371  0.000
# 3      0.000  0.000  0.000  0.071794 -0.997289  0.014828 -0.006371  0.000
# 4      0.000  0.000  0.000  0.071781 -0.997304  0.014123 -0.005663  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993 -0.113  0.031 -0.030  0.055940 -0.997639  0.011315  0.038186  0.000
# 23994 -0.133  0.024 -0.005 -0.065026 -0.995582  0.054444  0.040304  0.002
# 23995 -0.061  0.006 -0.005 -0.071750 -0.993774  0.055900  0.064349  0.002
# 23996  0.056 -0.014  0.010 -0.055565 -0.997462  0.044510  0.000692  0.002
# 23997  0.086 -0.023  0.007 -0.028915 -0.997655  0.042414 -0.045262  0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.959131  0.242007  0.070728    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.959131  0.242007  0.070728  0.000 -0.001  0.004
# 2      0.000  0.000  ...  0.959131  0.242007  0.070728 -0.002 -0.001  0.004
# 3      0.000  0.000  ...  0.959131  0.242007  0.070728  0.000 -0.001  0.003
# 4      0.000  0.000  ...  0.958666  0.243848  0.069993 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002 -0.001  ...  0.995579  0.063636  0.050912  0.011  0.003 -0.006
# 23994 -0.002  0.000  ...  0.995526  0.062216  0.052326 -0.001 -0.001  0.001
# 23995 -0.002 -0.001  ...  0.995388  0.066439  0.050911 -0.012 -0.003  0.006
# 23996 -0.001 -0.001  ...  0.995538  0.061510  0.051619 -0.023  0.001  0.010
# 23997  0.001  0.001  ...  0.995485  0.065038  0.050911 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
backward_90 = pd.read_csv('data/180_90_quat.csv', sep=",")
backward_90_without_speed = backward_90[backward_90.columns[:-1]]
euler_backward_90=backward_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
backward_90_diff = backward_90_without_speed.diff()
backward_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_backward_90
backward_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.756026 -0.654342  0.006012 -0.015006    NaN
# 1      0.000  0.000  0.000  0.755956 -0.654424  0.005980 -0.014990  0.000
# 2      0.000  0.000  0.000  0.755956 -0.654424  0.005980 -0.014990  0.000
# 3      0.000  0.000  0.000  0.755956 -0.654424  0.005980 -0.014990  0.000
# 4      0.000  0.000  0.000  0.755957 -0.654444  0.005982 -0.013991  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993  0.030  0.031 -0.113  0.744993 -0.665882  0.035002  0.019001  0.001
# 23994  0.005  0.024 -0.133  0.658002 -0.749963  0.066997 -0.009998  0.000
# 23995  0.005  0.006 -0.061  0.651969 -0.753439  0.085029  0.005975  0.001
# 23996 -0.010 -0.014  0.056  0.666022 -0.744603  0.031963 -0.030984  0.001
# 23997 -0.007 -0.023  0.086  0.685003 -0.725895 -0.002014 -0.061996 -0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.587382  0.221137 -0.121113    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.587382  0.221137 -0.121113  0.000 -0.001  0.004
# 2      0.000  0.000  ...  0.587382  0.221137 -0.121113 -0.002 -0.001  0.004
# 3      0.000  0.000  ...  0.587382  0.221137 -0.121113  0.000 -0.001  0.003
# 4      0.000  0.000  ...  0.586778  0.221919 -0.122934 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002  0.000  ...  0.670963  0.080998 -0.008998  0.011  0.003 -0.006
# 23994 -0.002  0.002  ...  0.669892  0.080993 -0.006993 -0.001 -0.001  0.001
# 23995 -0.002  0.002  ...  0.670704  0.082979 -0.010980 -0.012 -0.003  0.006
# 23996 -0.001  0.002  ...  0.668908  0.079994 -0.006994 -0.023  0.001  0.010
# 23997  0.001  0.001  ...  0.670835  0.081989 -0.009989 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
right_90 = pd.read_csv('data/270_90_quat.csv', sep=",")
right_90_without_speed = right_90[right_90.columns[:-1]]
euler_right_90=right_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
right_90_diff = right_90_without_speed.diff()
right_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_right_90
right_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.997281  0.071902 -0.006360 -0.014862    NaN
# 1      0.000  0.000  0.000  0.997289  0.071794 -0.006371 -0.014828  0.000
# 2      0.000  0.000  0.000  0.997289  0.071794 -0.006371 -0.014828  0.000
# 3      0.000  0.000  0.000  0.997289  0.071794 -0.006371 -0.014828  0.000
# 4      0.000  0.000  0.000  0.997304  0.071781 -0.005663 -0.014123  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993  0.113  0.031  0.030  0.997639  0.055940  0.038186 -0.011315  0.000
# 23994  0.133  0.024  0.005  0.995582 -0.065026  0.040304 -0.054444 -0.002
# 23995  0.061  0.006  0.005  0.993774 -0.071750  0.064349 -0.055900 -0.002
# 23996 -0.056 -0.014 -0.010  0.997462 -0.055565  0.000692 -0.044510 -0.002
# 23997 -0.086 -0.023 -0.007  0.997655 -0.028915 -0.045262 -0.042414 -0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ... -0.128447  0.070728 -0.242007    NaN    NaN    NaN
# 1      0.000  0.000  ... -0.128447  0.070728 -0.242007  0.000 -0.001  0.004
# 2      0.000  0.000  ... -0.128447  0.070728 -0.242007 -0.002 -0.001  0.004
# 3      0.000  0.000  ... -0.128447  0.070728 -0.242007  0.000 -0.001  0.003
# 4      0.000  0.000  ... -0.128837  0.069993 -0.243848 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002  0.001  ... -0.046694  0.050912 -0.063636  0.011  0.003 -0.006
# 23994 -0.002  0.000  ... -0.048156  0.052326 -0.062216 -0.001 -0.001  0.001
# 23995 -0.002  0.001  ... -0.046869  0.050911 -0.066439 -0.012 -0.003  0.006
# 23996 -0.001  0.001  ... -0.049560  0.051619 -0.061510 -0.023  0.001  0.010
# 23997  0.001 -0.001  ... -0.046780  0.050911 -0.065038 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
stop_90_diff.to_csv('stop_90_diff_quat.csv', index=False, header=True)
forward_90_diff.to_csv('0_90_diff_quat.csv', index=False, header=True)
left_90_diff.to_csv('90_90_diff_quat.csv', index=False, header=True)
backward_90_diff.to_csv('180_90_diff_quat.csv', index=False, header=True)
right_90_diff.to_csv('270_90_diff_quat.csv', index=False, header=True)
