# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
stop_90 = pd.read_csv('data/stop_90_quat.csv', sep=",")
stop_90_without_speed = stop_90[stop_90.columns[:-1]]
stop_90_without_speed
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0     -0.331  0.652  0.209  0.004000  0.677000  0.736000  0.010000  0.313
# 1     -0.331  0.652  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 2     -0.331  0.651  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 3     -0.331  0.652  0.209  0.004000  0.677000  0.735000  0.010000  0.313
# 4     -0.331  0.652  0.209  0.004000  0.678000  0.735000  0.010000  0.313
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 71991  0.176  0.614  0.125 -0.496378 -0.476591 -0.552437 -0.470407  0.174
# 71992  0.176  0.613  0.125 -0.495670 -0.477299 -0.552451 -0.470420  0.174
# 71993  0.176  0.613  0.125 -0.495670 -0.477299 -0.552451 -0.470420  0.174
# 71994  0.176  0.613  0.125 -0.495670 -0.477299 -0.552451 -0.470420  0.175
# 71995  0.176  0.613  0.125 -0.495670 -0.477299 -0.552451 -0.470420  0.175
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0      0.643  0.216  ...  0.616000  0.752000  0.071000 -0.028  2.288  0.179
# 1      0.643  0.216  ...  0.616000  0.753000  0.071000 -0.021  2.288  0.180
# 2      0.643  0.217  ...  0.616000  0.752000  0.071000 -0.013  2.288  0.181
# 3      0.643  0.216  ...  0.616000  0.752000  0.071000 -0.004  2.287  0.181
# 4      0.643  0.216  ...  0.616000  0.752000  0.071000  0.002  2.287  0.180
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.610 -0.133  ...  0.400271  0.528511  0.499996 -0.002  2.290  0.188
# 71992  0.610 -0.133  ...  0.400201  0.527681  0.500915 -0.009  2.289  0.189
# 71993  0.609 -0.133  ...  0.400201  0.527681  0.500915 -0.014  2.289  0.185
# 71994  0.610 -0.132  ...  0.400270  0.527820  0.500727 -0.022  2.293  0.180
# 71995  0.610 -0.133  ...  0.400201  0.527681  0.500915 -0.031  2.292  0.172
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0     -0.100 -0.025 -0.045  0.994
# 1     -0.106 -0.014 -0.054  0.993
# 2     -0.104 -0.001 -0.062  0.993
# 3     -0.106  0.014 -0.069  0.992
# 4     -0.105  0.023 -0.073  0.992
# ...      ...    ...    ...    ...
# 71991  0.016 -0.045 -0.003  0.999
# 71992  0.018 -0.071  0.004  0.997
# 71993  0.024 -0.083  0.010  0.996
# 71994  0.010 -0.094  0.026  0.995
# 71995  0.005 -0.117  0.057  0.991
#
# [71996 rows x 21 columns]

# %%
euler=stop_90[['e_r_x','e_r_y','e_r_z','e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
euler
# Out:
#           e_r_x     e_r_y     e_r_z     e_r_w     d_r_x     d_r_y     d_r_z  \
# 0      0.004000  0.677000  0.736000  0.010000  0.221000  0.616000  0.752000
# 1      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.753000
# 2      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.752000
# 3      0.004000  0.677000  0.735000  0.010000  0.221000  0.616000  0.752000
# 4      0.004000  0.678000  0.735000  0.010000  0.221000  0.616000  0.752000
# ...         ...       ...       ...       ...       ...       ...       ...
# 71991 -0.496378 -0.476591 -0.552437 -0.470407  0.557192  0.400271  0.528511
# 71992 -0.495670 -0.477299 -0.552451 -0.470420  0.557204  0.400201  0.527681
# 71993 -0.495670 -0.477299 -0.552451 -0.470420  0.557204  0.400201  0.527681
# 71994 -0.495670 -0.477299 -0.552451 -0.470420  0.557192  0.400270  0.527820
# 71995 -0.495670 -0.477299 -0.552451 -0.470420  0.557204  0.400201  0.527681
#
#           d_r_w
# 0      0.071000
# 1      0.071000
# 2      0.071000
# 3      0.071000
# 4      0.071000
# ...         ...
# 71991  0.499996
# 71992  0.500915
# 71993  0.500915
# 71994  0.500727
# 71995  0.500915
#
# [71996 rows x 8 columns]

# %%
stop_90_diff = stop_90_without_speed.diff()
stop_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x         e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN       NaN           NaN       NaN       NaN    NaN
# 1        0.0  0.000    0.0  0.000000  0.000000e+00 -0.001000  0.000000  0.000
# 2        0.0 -0.001    0.0  0.000000  0.000000e+00  0.000000  0.000000  0.000
# 3        0.0  0.001    0.0  0.000000  0.000000e+00  0.000000  0.000000  0.000
# 4        0.0  0.000    0.0  0.000000  1.000000e-03  0.000000  0.000000  0.000
# ...      ...    ...    ...       ...           ...       ...       ...    ...
# 71991    0.0  0.001    0.0 -0.000003  2.240464e-07 -0.000649  0.000764 -0.002
# 71992    0.0 -0.001    0.0  0.000708 -7.073143e-04 -0.000014 -0.000013  0.000
# 71993    0.0  0.000    0.0  0.000000  0.000000e+00  0.000000  0.000000  0.000
# 71994    0.0  0.000    0.0  0.000000  0.000000e+00  0.000000  0.000000  0.001
# 71995    0.0  0.000    0.0  0.000000  0.000000e+00  0.000000  0.000000  0.000
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...       NaN       NaN       NaN    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.000000  0.001000  0.000000  0.007  0.000  0.001
# 2      0.000  0.001  ...  0.000000 -0.001000  0.000000  0.008  0.000  0.001
# 3      0.000 -0.001  ...  0.000000  0.000000  0.000000  0.009 -0.001  0.000
# 4      0.000  0.000  ...  0.000000  0.000000  0.000000  0.006  0.000 -0.001
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.000  0.000  ... -0.000696 -0.000086 -0.000137 -0.024  0.002  0.005
# 71992  0.000  0.000  ... -0.000071 -0.000830  0.000918 -0.007 -0.001  0.001
# 71993 -0.001  0.000  ...  0.000000  0.000000  0.000000 -0.005  0.000 -0.004
# 71994  0.001  0.001  ...  0.000069  0.000138 -0.000187 -0.008  0.004 -0.005
# 71995  0.000 -0.001  ... -0.000069 -0.000138  0.000187 -0.009 -0.001 -0.008
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1     -0.006  0.011 -0.009 -0.001
# 2      0.002  0.013 -0.008  0.000
# 3     -0.002  0.015 -0.007 -0.001
# 4      0.001  0.009 -0.004  0.000
# ...      ...    ...    ...    ...
# 71991 -0.002 -0.098  0.008  0.001
# 71992  0.002 -0.026  0.007 -0.002
# 71993  0.006 -0.012  0.006 -0.001
# 71994 -0.014 -0.011  0.016 -0.001
# 71995 -0.005 -0.023  0.031 -0.004
#
# [71996 rows x 21 columns]

# %%
stop_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler
stop_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.004000  0.677000  0.736000  0.010000    NaN
# 1        0.0  0.000    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 2        0.0 -0.001    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 3        0.0  0.001    0.0  0.004000  0.677000  0.735000  0.010000  0.000
# 4        0.0  0.000    0.0  0.004000  0.678000  0.735000  0.010000  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 71991    0.0  0.001    0.0 -0.496378 -0.476591 -0.552437 -0.470407 -0.002
# 71992    0.0 -0.001    0.0 -0.495670 -0.477299 -0.552451 -0.470420  0.000
# 71993    0.0  0.000    0.0 -0.495670 -0.477299 -0.552451 -0.470420  0.000
# 71994    0.0  0.000    0.0 -0.495670 -0.477299 -0.552451 -0.470420  0.001
# 71995    0.0  0.000    0.0 -0.495670 -0.477299 -0.552451 -0.470420  0.000
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.616000  0.752000  0.071000    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.616000  0.753000  0.071000  0.007  0.000  0.001
# 2      0.000  0.001  ...  0.616000  0.752000  0.071000  0.008  0.000  0.001
# 3      0.000 -0.001  ...  0.616000  0.752000  0.071000  0.009 -0.001  0.000
# 4      0.000  0.000  ...  0.616000  0.752000  0.071000  0.006  0.000 -0.001
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 71991  0.000  0.000  ...  0.400271  0.528511  0.499996 -0.024  0.002  0.005
# 71992  0.000  0.000  ...  0.400201  0.527681  0.500915 -0.007 -0.001  0.001
# 71993 -0.001  0.000  ...  0.400201  0.527681  0.500915 -0.005  0.000 -0.004
# 71994  0.001  0.001  ...  0.400270  0.527820  0.500727 -0.008  0.004 -0.005
# 71995  0.000 -0.001  ...  0.400201  0.527681  0.500915 -0.009 -0.001 -0.008
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1     -0.006  0.011 -0.009 -0.001
# 2      0.002  0.013 -0.008  0.000
# 3     -0.002  0.015 -0.007 -0.001
# 4      0.001  0.009 -0.004  0.000
# ...      ...    ...    ...    ...
# 71991 -0.002 -0.098  0.008  0.001
# 71992  0.002 -0.026  0.007 -0.002
# 71993  0.006 -0.012  0.006 -0.001
# 71994 -0.014 -0.011  0.016 -0.001
# 71995 -0.005 -0.023  0.031 -0.004
#
# [71996 rows x 21 columns]

# %%
forward_90 = pd.read_csv('data/0_90_quat.csv', sep=",")
forward_90_without_speed = forward_90[forward_90.columns[:-1]]
euler_forward_90=forward_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
forward_90_diff = forward_90_without_speed.diff()
forward_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x', 'd_r_y', 'd_r_z', 'd_r_w']]=euler_forward_90
forward_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z  e_r_x  e_r_y  e_r_z  e_r_w  d_t_x  d_t_y  d_t_z  \
# 0        NaN    NaN    NaN  0.006 -0.654 -0.756  0.015    NaN    NaN    NaN
# 1      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 2      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 3      0.000  0.000  0.000  0.006 -0.655 -0.756  0.015  0.000  0.000  0.000
# 4      0.000  0.000  0.000  0.006 -0.655 -0.756  0.014  0.000  0.000  0.000
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 23993 -0.030  0.031  0.113 -0.035  0.666  0.745  0.019 -0.001 -0.002  0.000
# 23994 -0.005  0.024  0.133  0.067 -0.750 -0.658  0.010  0.000 -0.002 -0.002
# 23995 -0.005  0.006  0.061 -0.085  0.753  0.652  0.006 -0.001 -0.002 -0.002
# 23996  0.010 -0.014 -0.056  0.032 -0.745 -0.666  0.031 -0.001 -0.001 -0.002
# 23997  0.007 -0.023 -0.086 -0.002 -0.726 -0.685  0.062  0.001  0.001 -0.001
#
#        ...  d_r_y  d_r_z  d_r_w  c_t_x  c_t_y  c_t_z  c_r_x  c_r_y  c_r_z  \
# 0      ...  0.587  0.769  0.121    NaN    NaN    NaN    NaN    NaN    NaN
# 1      ...  0.587  0.769  0.121  0.000 -0.001  0.004  0.002  0.005  0.001
# 2      ...  0.587  0.769  0.121 -0.002 -0.001  0.004  0.003 -0.002 -0.001
# 3      ...  0.587  0.769  0.121  0.000 -0.001  0.003  0.004 -0.001  0.000
# 4      ...  0.587  0.769  0.123 -0.002 -0.001  0.004  0.002 -0.001  0.000
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 23993  ...  0.671  0.737  0.009  0.011  0.003 -0.006  0.003 -0.001 -0.006
# 23994  ...  0.670  0.738  0.007 -0.001 -0.001  0.001 -0.005  0.004  0.000
# 23995  ...  0.671  0.737  0.011 -0.012 -0.003  0.006  0.005  0.006  0.006
# 23996  ...  0.669  0.739  0.007 -0.023  0.001  0.010  0.001 -0.001  0.011
# 23997  ...  0.671  0.737  0.010 -0.030  0.001  0.004  0.005 -0.011  0.016
#
#        c_r_w
# 0        NaN
# 1      0.000
# 2      0.000
# 3      0.000
# 4      0.000
# ...      ...
# 23993  0.000
# 23994  0.000
# 23995  0.000
# 23996  0.001
# 23997  0.000
#
# [23998 rows x 21 columns]

# %%
left_90 = pd.read_csv('data/90_90_quat.csv', sep=",")
left_90_without_speed =left_90[left_90.columns[:-1]]
euler_left_90=left_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
left_90_diff =left_90_without_speed.diff()
left_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_left_90
left_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.466677 -0.458186 -0.524201  0.545427    NaN
# 1      0.000  0.000  0.000  0.467419 -0.458945 -0.523569  0.544761  0.000
# 2      0.000  0.000  0.000  0.467419 -0.458945 -0.523569  0.544761  0.000
# 3      0.000  0.000  0.000  0.467419 -0.458945 -0.523569  0.544761  0.000
# 4      0.000  0.000  0.000  0.467419 -0.458943 -0.524290  0.544069  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993 -0.113  0.031 -0.030  0.495686 -0.446189 -0.540151  0.513271  0.000
# 23994 -0.133  0.024 -0.005  0.577703 -0.482954 -0.458183  0.472317  0.002
# 23995 -0.061  0.006 -0.005  0.592602 -0.472347 -0.465531  0.457157  0.002
# 23996  0.056 -0.014  0.010  0.549392 -0.504165 -0.448756  0.492549  0.002
# 23997  0.086 -0.023  0.007  0.511940 -0.514775 -0.440456  0.528132  0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.571340  0.629763 -0.458301    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.571340  0.629763 -0.458301  0.000 -0.001  0.004
# 2      0.000  0.000  ...  0.571340  0.629763 -0.458301 -0.002 -0.001  0.004
# 3      0.000  0.000  ...  0.571340  0.629763 -0.458301  0.000 -0.001  0.003
# 4      0.000  0.000  ...  0.572050  0.630483 -0.456736 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002 -0.001  ...  0.531744  0.527471 -0.514753  0.011  0.003 -0.006
# 23994 -0.002  0.000  ...  0.531037  0.526704 -0.516832 -0.001 -0.001  0.001
# 23995 -0.002 -0.001  ...  0.533157  0.528668 -0.513190 -0.012 -0.003  0.006
# 23996 -0.001 -0.001  ...  0.529623  0.527425 -0.517548 -0.023  0.001  0.010
# 23997  0.001  0.001  ...  0.532451  0.528071 -0.513972 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
backward_90 = pd.read_csv('data/180_90_quat.csv', sep=",")
backward_90_without_speed = backward_90[backward_90.columns[:-1]]
euler_backward_90=backward_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
backward_90_diff = backward_90_without_speed.diff()
backward_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_backward_90
backward_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.653977  0.006005  0.015009  0.756342    NaN
# 1      0.000  0.000  0.000  0.655038  0.005992  0.014985  0.755423  0.000
# 2      0.000  0.000  0.000  0.655038  0.005992  0.014985  0.755423  0.000
# 3      0.000  0.000  0.000  0.655038  0.005992  0.014985  0.755423  0.000
# 4      0.000  0.000  0.000  0.655037  0.005993  0.013986  0.755444  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993  0.030  0.031 -0.113  0.666006  0.034999 -0.019007  0.744882  0.001
# 23994  0.005  0.024 -0.133  0.749998  0.066997  0.009995  0.657963  0.000
# 23995  0.005  0.006 -0.061  0.753032  0.085033 -0.005922  0.652439  0.001
# 23996 -0.010 -0.014  0.056  0.744977  0.031980  0.030966  0.665603  0.001
# 23997 -0.007 -0.023  0.086  0.725997 -0.002004  0.061996  0.684895 -0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ...  0.221066  0.121242 -0.769377    NaN    NaN    NaN
# 1      0.000  0.000  ...  0.221066  0.121242 -0.769377  0.000 -0.001  0.004
# 2      0.000  0.000  ...  0.221066  0.121242 -0.769377 -0.002 -0.001  0.004
# 3      0.000  0.000  ...  0.221066  0.121242 -0.769377  0.000 -0.001  0.003
# 4      0.000  0.000  ...  0.221961  0.122858 -0.768780 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002  0.000  ...  0.080998  0.008993 -0.736963  0.011  0.003 -0.006
# 23994 -0.002  0.002  ...  0.080994  0.006981 -0.737892 -0.001 -0.001  0.001
# 23995 -0.002  0.002  ...  0.082983  0.010945 -0.736705 -0.012 -0.003  0.006
# 23996 -0.001  0.002  ...  0.079995  0.006984 -0.738908 -0.023  0.001  0.010
# 23997  0.001  0.001  ...  0.081991  0.009970 -0.736835 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
right_90 = pd.read_csv('data/270_90_quat.csv', sep=",")
right_90_without_speed = right_90[right_90.columns[:-1]]
euler_right_90=right_90[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]
right_90_diff = right_90_without_speed.diff()
right_90_diff[['e_r_x','e_r_y','e_r_z', 'e_r_w', 'd_r_x','d_r_y','d_r_z','d_r_w']]=euler_right_90
right_90_diff
# Out:
#        e_t_x  e_t_y  e_t_z     e_r_x     e_r_y     e_r_z     e_r_w  d_t_x  \
# 0        NaN    NaN    NaN  0.458186  0.466677  0.545427  0.524201    NaN
# 1      0.000  0.000  0.000  0.458945  0.467419  0.544761  0.523569  0.000
# 2      0.000  0.000  0.000  0.458945  0.467419  0.544761  0.523569  0.000
# 3      0.000  0.000  0.000  0.458945  0.467419  0.544761  0.523569  0.000
# 4      0.000  0.000  0.000  0.458943  0.467419  0.544069  0.524290  0.000
# ...      ...    ...    ...       ...       ...       ...       ...    ...
# 23993  0.113  0.031  0.030  0.446189  0.495686  0.513271  0.540151  0.000
# 23994  0.133  0.024  0.005  0.482954  0.577703  0.472317  0.458183 -0.002
# 23995  0.061  0.006  0.005  0.472347  0.592602  0.457157  0.465531 -0.002
# 23996 -0.056 -0.014 -0.010  0.504165  0.549392  0.492549  0.448756 -0.002
# 23997 -0.086 -0.023 -0.007  0.514775  0.511940  0.528132  0.440456 -0.001
#
#        d_t_y  d_t_z  ...     d_r_y     d_r_z     d_r_w  c_t_x  c_t_y  c_t_z  \
# 0        NaN    NaN  ... -0.258706 -0.458301 -0.629763    NaN    NaN    NaN
# 1      0.000  0.000  ... -0.258706 -0.458301 -0.629763  0.000 -0.001  0.004
# 2      0.000  0.000  ... -0.258706 -0.458301 -0.629763 -0.002 -0.001  0.004
# 3      0.000  0.000  ... -0.258706 -0.458301 -0.629763  0.000 -0.001  0.003
# 4      0.000  0.000  ... -0.258150 -0.456736 -0.630483 -0.002 -0.001  0.004
# ...      ...    ...  ...       ...       ...       ...    ...    ...    ...
# 23993 -0.002  0.001  ... -0.417196 -0.514753 -0.527471  0.011  0.003 -0.006
# 23994 -0.002  0.000  ... -0.416494 -0.516832 -0.526704 -0.001 -0.001  0.001
# 23995 -0.002  0.001  ... -0.415801 -0.513190 -0.528668 -0.012 -0.003  0.006
# 23996 -0.001  0.001  ... -0.416493 -0.517548 -0.527425 -0.023  0.001  0.010
# 23997  0.001 -0.001  ... -0.416498 -0.513972 -0.528071 -0.030  0.001  0.004
#
#        c_r_x  c_r_y  c_r_z  c_r_w
# 0        NaN    NaN    NaN    NaN
# 1      0.002  0.005  0.001  0.000
# 2      0.003 -0.002 -0.001  0.000
# 3      0.004 -0.001  0.000  0.000
# 4      0.002 -0.001  0.000  0.000
# ...      ...    ...    ...    ...
# 23993  0.003 -0.001 -0.006  0.000
# 23994 -0.005  0.004  0.000  0.000
# 23995  0.005  0.006  0.006  0.000
# 23996  0.001 -0.001  0.011  0.001
# 23997  0.005 -0.011  0.016  0.000
#
# [23998 rows x 21 columns]

# %%
stop_90_diff.to_csv('stop_90_diff_quat.csv', index=False, header=True)
forward_90_diff.to_csv('0_90_diff_quat.csv', index=False, header=True)
left_90_diff.to_csv('90_90_diff_quat.csv', index=False, header=True)
backward_90_diff.to_csv('180_90_diff_quat.csv', index=False, header=True)
right_90_diff.to_csv('270_90_diff_quat.csv', index=False, header=True)
